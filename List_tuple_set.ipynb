# %%
a = ['a',2,'c',3,'d',4]
for i in a:
    if str(i).isdigit():
        print(f"Digit:  {i}")
    else:
        print(f"Alphabet: {i}")
# Out:
# Alphabet: a
# Digit:  2
# Alphabet: c
# Digit:  3
# Alphabet: d
# Digit:  4

# %%
a = ['a',2,'c',3,'d',4]
a[1:3]=[4,4]
print(a)
# Out:
# ['a', 4, 4, 3, 'd', 4]

# %%
a = ['a',2,'c',3,'d',4]
a[3:4]=[4,4]
print(a)
# Out:
# ['a', 2, 'c', 4, 4, 'd', 4]

# %%
a = ['a',2,'c',3,'d',4]
a.insert(1,1)#it insert the element at given index
print(a)
# Out:
# ['a', 1, 2, 'c', 3, 'd', 4]

# %%
a = ['a',2,'c',3,'d',4]
a.append('abc')#it add character in last
print(a)

# %%
a = ['a',2,'c',3,'d',4]
a.pop(2)#it remove the character from given space according to index
print(a)

# %%
a = ['a',2,'c',3,'d',4]
a.extend(['e',5])#it add the other list in last
print(a)

# %%
a = ['a',4,'c',3,'d',4]
print(a.count(4))#it count how many time the character appear

# %%
a = ['a',4,'c',3,'d',4]
print(a.index('a'))#it used to find out given character index
# Out:
# 0

# %%
a = [20,40,12,18,14,60]
a.reverse()#it reverse the element
print(a)
# Out:
# [60, 14, 18, 12, 40, 20]

# %%
a = [20,40,12,18,14,60]
a.sort()#sort the element in acsending order
print(a)
# Out:
# [12, 14, 18, 20, 40, 60]

# %%
a = [20,40,12,18,14,60]
a.sort(reverse=True)#sort the element in decsending order
print(a)
# Out:
# [60, 40, 20, 18, 14, 12]

# %%
a = [20,40,12,18,14,60]
a.remove(12)#it remove the given chracter
print(a)
# Out:
# [20, 40, 18, 14, 60]

# %%
a = ['abc','def','ghi','klm']
b = []
for i in a:
   b.append(i.upper())
b.reverse()
b.insert(2,'NOP')
b.extend(['QRS','TUV'])
b.sort()
print(b)
# Out:
# ['ABC', 'DEF', 'GHI', 'KLM', 'NOP', 'QRS', 'TUV']

# %%
a = ['abc','def','ghi','klm']
a.reverse()
print(a)
# Out:
# ['klm', 'ghi', 'def', 'abc']

# %%
a = ['abc','def','ghi','klm']
a.insert(2,'nop')
print(a)
# Out:
# ['abc', 'def', 'nop', 'ghi', 'klm']

# %%
a = ['Ramesh','Naresh','Mangesh','Naresh']
b = []
for i in a:
     if i not in b :
         b.append(i)
print(b)
# Out:
# ['Ramesh', 'Naresh', 'Mangesh']

# %%
a = ['Ramesh','Naresh','Mangesh','Naresh','Suresh']
b = []
b.insert(0,a[-2])
a.pop(-2)
b.extend(a)
print(b)
# Out:
# ['Naresh', 'Ramesh', 'Naresh', 'Mangesh', 'Suresh']

# %%
a = [20,50,30,60,10]

for i in range (len(a)):
    for j in range(i+1,len(a)):
        if a [i]>a[j]:
           a[i],a[j]=a[j],a[i]
print(a)
# Out:
# [10, 20, 30, 50, 60]

# %%
a = [20,50,30,60,10]
print(a[::-1])
# Out:
# [10, 60, 30, 50, 20]

# %%
a = [10,20,30,40,50,60]
b = []
for i in range (len(a)-1,-1,-1):
    b.append(a[i])
print(b)
# Out:
# [60, 50, 40, 30, 20, 10]

# %%
a = [1,2,3,4,5]
b = a
if b == sorted(a):
    print("Given list is sorted")
else:
    print("Given list is not sorted")
# Out:
# Given list is sorted

# %%
a = 1,2,'abc'
b = list(a)
b[2]=3
print(tuple(b))
# Out:
# (1, 2, 3)

# %%
a = (1,2,3,4,6,5)
b = list(a)
b.sort(reverse =True)
print(tuple(b))
# Out:
# (6, 5, 4, 3, 2, 2, 1)

# %%
a = (1,1,2)
del(a)
print(a)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 3
#       1 a = (1,1,2)
#       2 del(a)
# ----> 3 print(a)
#
# NameError: name 'a' is not defined

# %%
a = {1,2,2,3}
print(a)
# Out:
# {1, 2, 3}

# %%
a = (1,2,3,6,4)
sum = 0
for i in a:
    sum=sum+i
print(sum)
# Out:
# 16

# %%
a = set([1,2,3,3,4])
print(a)
# Out:
# {1, 2, 3, 4}

# %%
a = {'p','y','t','h','o','n'}
for i in a:
    print(i)
# Out:
# p
# h
# o
# y
# t
# n

# %%
a = {'p','y','t','h','o','n'}
a.add('s')
a.add(5)
a.add(2.4)
a.add((1,2,3))
print(a)
# Out:
# {2.4, 5, 'y', 't', 'o', 'p', (1, 2, 3), 'h', 's', 'n'}

# %%
a = [20,30,60,72]
for i in a:
    c =i%12
    print(f"Remainder={c}")
# Out:
# Remainder=8
# Remainder=6
# Remainder=0
# Remainder=0

# %%
a = {20,30,60,72}
print(a)#FOR FINDING A INDEX IN SET , FORMULA IS (VALUE % MEMORY SIZE),IF THE NO COME IN SAME INDEX SO, ITS CALLED COLLISION
#h(x)=x%size
# Out:
# {72, 20, 30, 60}

# %%
a = {1,2,3}
a.add(4)

print(a)
# Out:
# set()

# %%
a={1,2,3}
b = {3,4,5}
print(a.difference(b))
print(b.difference(a))
# Out:
# {1, 2}
# {4, 5}

# %%
a={1,2,3}
a.discard(2)
print(a)
# Out:
# {1, 3}

# %%
a={1,2,3}
a.clear()
print(a)
# Out:
# set()

# %%
a={1,2,3}
b = {2,4}

print(a.intersection(b))
# Out:
# {2}

# %%
a={20,40,3}
a.pop()
print(a)
# Out:
# {3, 20}

# %%
a={1,2,3}
a.remove(3)
print(a)
# Out:
# {1, 2}

# %%
a={1,2,3}
a.update({4,5})
print(a)
# Out:
# {1, 2, 3, 4, 5}

# %%
a={1,2,3}
b ={4,5}

print(a.union(b))
# Out:
# {1, 2, 3, 4, 5}

# %%
a={1,2,3}
b = a.copy()
print(b)
# Out:
# {1, 2, 3}

# %%
a = {1,2,3,4,5,6}
b = {55,77,1,2}
# b.issubset(a)
# a.issuperset(b)
# a.isdisjoint(b)
a.symmetric_difference(b)
# Out:
# {3, 4, 5, 6, 55, 77}

# %%
a = {1,2,3}
b = {3,4,5}
print(a&b)#intersection
print(a-b)#differance
print(b-a)
print(a^b)#symetric differance
print(a<=b)#subset
print(a>=b)#superset
print(a|b)#union
print(a>b)#proper subset
# Out:
# {3}
# {1, 2}
# {4, 5}
# {1, 2, 4, 5}
# False
# False
# {1, 2, 3, 4, 5}
# False

# %%
#list compression
a = [1,2,3,4,5]
b ={x for x in a}#{expression for value in iterable}
print(b)
# Out:
# {1, 2, 3, 4, 5}

# %%
a = "programming"
b ={x for x in a}
print(b)
# Out:
# {'g', 'r', 'o', 'n', 'm', 'i', 'p', 'a'}

# %%
a = "programming"
b =[x for x in a]
print(b)
# Out:
# ['p', 'r', 'o', 'g', 'r', 'a', 'm', 'm', 'i', 'n', 'g']

# %%
a = "programming"
b =(x for x in a)
print(b)
# Out:
# <generator object <genexpr> at 0x000001DE0890D8A0>

# %%
a = {1,2,3,4,5,6}
b = {x for x in a if x%2==0}
print(f"Even No = {b}")
b = {x for x in a if x%2!=0}
print(f"Odd No = {b}")
# Out:
# Even No = {2, 4, 6}
# Odd No = {1, 3, 5}

# %%
a = {1,2,3,4,5,6}
b = {x if x%2==0 else -x for x in a}
print(b)
# Out:
# {2, 4, 6, -5, -3, -1}
